# %%
import numpy as np
import pandas as pd

# %%
index=pd.date_range('1/2017',periods=6,freq='M')

# %%
index
# Out:
# DatetimeIndex(['2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
from pyecharts import Geo

# %%
df=pd.read_csv('C:\Workspace\数据源\漫入物联网号码信息_袁铁山.csv',encoding='gbk',engine='python')

# %%
df
# Out:
#                 手机号码 来源省份名称 来源地市名称 停留时间最长地市名称 停留时间最长区县名称  经过地市个数  经过区县个数  \
# 0      1064700320002    NaN    NaN        NaN        NaN     NaN     NaN
# 1      1064700320020    NaN    NaN        NaN        NaN     NaN     NaN
# 2      1064700320025    NaN    NaN        NaN        NaN     NaN     NaN
# 3      1064700554058    北京市    北京市         绍兴         越城       1     1.0
# 4      1064702226292    北京市    北京市         绍兴         越城  100.0%     1.0
# 5      1064703801189    北京市    北京市         绍兴         诸暨  100.0%     1.0
# 6      1064703858006    NaN    NaN        NaN        NaN     NaN     NaN
# 7      1064703858114    北京市    北京市         绍兴         越城  100.0%     1.0
# 8      1064703858119    NaN    NaN        NaN        NaN     NaN     NaN
# 9      1064703858187    北京市    北京市         绍兴         绍兴  100.0%     1.0
# 10     1064703858209    北京市    北京市         绍兴         越城  100.0%     1.0
# 11     1064703858213    北京市    北京市         绍兴         越城  100.0%     1.0
# ...

# %%
df1=df.dropna(how='any',)

# %%
df1.reset_index(drop=True,inplace=True)

# %%
type(df1[['手机号码']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1.iloc[:,0:6]
# Out:
#                 手机号码 来源省份名称 来源地市名称 停留时间最长地市名称 停留时间最长区县名称  经过地市个数
# 0      1064700554058    北京市    北京市         绍兴         越城       1
# 1      1064702226292    北京市    北京市         绍兴         越城  100.0%
# 2      1064703801189    北京市    北京市         绍兴         诸暨  100.0%
# 3      1064703858114    北京市    北京市         绍兴         越城  100.0%
# 4      1064703858187    北京市    北京市         绍兴         绍兴  100.0%
# 5      1064703858213    北京市    北京市         绍兴         越城  100.0%
# 6      1064703858317    北京市    北京市         绍兴         越城  100.0%
# 7      1064703858678    北京市    北京市         绍兴         绍兴  100.0%
# 8      1064703858691    北京市    北京市         绍兴         越城  100.0%
# 9      1064703858704    北京市    北京市         绍兴         绍兴  100.0%
# 10     1064703859028    北京市    北京市         绍兴         越城       1
# 11     1064703859203    北京市    北京市         绍兴         越城       1
# 12     1064703859889    北京市    北京市         绍兴         越城       1
# ...

# %%
df1[['手机号码', '来源省份名称', '来源地市名称', '停留时间最长地市名称', '停留时间最长区县名称', '经过地市个数']]
# Out:
#                 手机号码 来源省份名称 来源地市名称 停留时间最长地市名称 停留时间最长区县名称  经过地市个数
# 0      1064700554058    北京市    北京市         绍兴         越城       1
# 1      1064702226292    北京市    北京市         绍兴         越城  100.0%
# 2      1064703801189    北京市    北京市         绍兴         诸暨  100.0%
# 3      1064703858114    北京市    北京市         绍兴         越城  100.0%
# 4      1064703858187    北京市    北京市         绍兴         绍兴  100.0%
# 5      1064703858213    北京市    北京市         绍兴         越城  100.0%
# 6      1064703858317    北京市    北京市         绍兴         越城  100.0%
# 7      1064703858678    北京市    北京市         绍兴         绍兴  100.0%
# 8      1064703858691    北京市    北京市         绍兴         越城  100.0%
# 9      1064703858704    北京市    北京市         绍兴         绍兴  100.0%
# 10     1064703859028    北京市    北京市         绍兴         越城       1
# 11     1064703859203    北京市    北京市         绍兴         越城       1
# 12     1064703859889    北京市    北京市         绍兴         越城       1
# ...

# %%
geo_cites_coord={df1.iloc[i]['手机号码']:[df1.iloc[i]['居住地经度bd'],df1.iloc[i]['居住地纬度bd']] for i in range(len(df1))}

# %%
list(df1)
# Out:
# ['手机号码',
#  '来源省份名称',
#  '来源地市名称',
#  '停留时间最长地市名称',
#  '停留时间最长区县名称',
#  '经过地市个数',
#  '经过区县个数',
#  '连接基站个数',
#  '最大速度',
#  '平均速度',
#  '工作地基站名称',
#  '工作地覆盖区域',
#  '工作地经度bd',
#  '工作地纬度bd',
#  '居住地基站名称',
#  '居住地覆盖区域',
#  '居住地经度bd',
#  '居住地纬度bd',
#  '疑似应用类型']

# %%
grouped=df1.groupby(['来源省份名称','来源地市名称'])

# %%
grouped[['连接基站个数']].agg([np.mean,np.median,np.sum])
# Out:
#                    连接基站个数
#                      mean median      sum
# 来源省份名称 来源地市名称
# 上海市    上海市      10.675609    3.0  34621.0
# 北京市    北京市       9.794837    4.0   7209.0
# 吉林省    长春市/九台市  51.333333   43.0    154.0
# 四川省    成都市       2.827586    1.0   1066.0
# 天津市    天津市       9.840580    2.0    679.0
# 宁夏     银川市      22.833333   14.5    411.0
# 安徽省    合肥市      13.000000    1.5    104.0
# 山东省    济南市      19.634486   13.0  46573.0
# 山西省    太原市      20.416667   21.0    490.0
# 广东省    广州市       5.959953    2.0  20240.0
# 广西     南宁市       1.529412    1.0     26.0
# 江苏省    南京市      13.974194    3.0  19494.0
# 江西省    南昌市      15.548611    2.0   2239.0
# 河北省    石家庄市      2.883610    2.0   2428.0
# 河南省    郑州市       9.166867    2.0   7636.0
# 湖南省    长沙市      33.250000   30.0    266.0
# 福建省    福州市       6.076495    1.0   4369.0
# 辽宁省    沈阳市      22.824121   19.0   4542.0
# 重庆市    重庆市       6.730897    2.0   6078.0
# 陕西省    西安市       1.963636    1.0    108.0
# ...

# %%
grouped.agg({'连接基站个数':[np.mean,np.median],'经过地市个数':np.sum})
# Out:
#                    连接基站个数         \
#                      mean median
# 来源省份名称 来源地市名称
# 上海市    上海市      10.675609    3.0
# 北京市    北京市       9.794837    4.0
# 吉林省    长春市/九台市  51.333333   43.0
# 四川省    成都市       2.827586    1.0
# 天津市    天津市       9.840580    2.0
# 宁夏     银川市      22.833333   14.5
# 安徽省    合肥市      13.000000    1.5
# 山东省    济南市      19.634486   13.0
# 山西省    太原市      20.416667   21.0
# 广东省    广州市       5.959953    2.0
# 广西     南宁市       1.529412    1.0
# 江苏省    南京市      13.974194    3.0
# 江西省    南昌市      15.548611    2.0
# 河北省    石家庄市      2.883610    2.0
# 河南省    郑州市       9.166867    2.0
# 湖南省    长沙市      33.250000   30.0
# 福建省    福州市       6.076495    1.0
# 辽宁省    沈阳市      22.824121   19.0
# 重庆市    重庆市       6.730897    2.0
# 陕西省    西安市       1.963636    1.0
# 黑龙江省   哈尔滨市      2.215517    2.0
#
#                                                            经过地市个数
#                                                               sum
# 来源省份名称 来源地市名称
# ...

# %%
df2=df1['经过地市个数'].replace('100.0%',1)

# %%
df1['经过地市个数']=df2
# Out:
# c:\users\l\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.loc[df1['经过地市个数']=='100.0%','经过地市个数']=1
# Out:
# c:\users\l\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df1[['经过地市个数']]=df1[['经过地市个数']].astype(int)
# Out:
# c:\users\l\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
df1
# Out:
#                 手机号码 来源省份名称 来源地市名称 停留时间最长地市名称 停留时间最长区县名称  经过地市个数  经过区县个数  \
# 3      1064700554058    北京市    北京市         绍兴         越城       1     1.0
# 4      1064702226292    北京市    北京市         绍兴         越城       1     1.0
# 5      1064703801189    北京市    北京市         绍兴         诸暨       1     1.0
# 7      1064703858114    北京市    北京市         绍兴         越城       1     1.0
# 9      1064703858187    北京市    北京市         绍兴         绍兴       1     1.0
# 11     1064703858213    北京市    北京市         绍兴         越城       1     1.0
# 12     1064703858317    北京市    北京市         绍兴         越城       1     1.0
# 14     1064703858678    北京市    北京市         绍兴         绍兴       1     2.0
# 15     1064703858691    北京市    北京市         绍兴         越城       1     1.0
# 16     1064703858704    北京市    北京市         绍兴         绍兴       1     1.0
# 18     1064703859028    北京市    北京市         绍兴         越城       1     1.0
# 19     1064703859203    北京市    北京市         绍兴         越城       1     1.0
# ...

# %%
list(df1)
# Out:
# ['手机号码',
#  '来源省份名称',
#  '来源地市名称',
#  '停留时间最长地市名称',
#  '停留时间最长区县名称',
#  '经过地市个数',
#  '经过区县个数',
#  '连接基站个数',
#  '最大速度',
#  '平均速度',
#  '工作地基站名称',
#  '工作地覆盖区域',
#  '工作地经度bd',
#  '工作地纬度bd',
#  '居住地基站名称',
#  '居住地覆盖区域',
#  '居住地经度bd',
#  '居住地纬度bd',
#  '疑似应用类型']

# %%
grouped=df1.groupby(['来源省份名称','来源地市名称'])

# %%
grouped[['经过地市个数']].mean()
# Out:
#                   经过地市个数
# 来源省份名称 来源地市名称
# 上海市    上海市      1.110700
# 北京市    北京市      1.125000
# 吉林省    长春市/九台市  2.333333
# 四川省    成都市      1.026525
# 天津市    天津市      1.246377
# 宁夏     银川市      1.111111
# 安徽省    合肥市      1.000000
# 山东省    济南市      1.322934
# 山西省    太原市      1.291667
# 广东省    广州市      1.043286
# 广西     南宁市      1.000000
# 江苏省    南京市      1.235125
# 江西省    南昌市      1.361111
# 河北省    石家庄市     1.024941
# 河南省    郑州市      1.092437
# 湖南省    长沙市      1.625000
# 福建省    福州市      1.059805
# 辽宁省    沈阳市      1.241206
# 重庆市    重庆市      1.058693
# 陕西省    西安市      1.072727
# 黑龙江省   哈尔滨市     1.034483

# %%
grouped.agg({'连接基站个数':[np.mean,np.median],'经过地市个数':np.mean})
# Out:
#                    连接基站个数           经过地市个数
#                      mean median      mean
# 来源省份名称 来源地市名称
# 上海市    上海市      10.675609    3.0  1.110700
# 北京市    北京市       9.794837    4.0  1.125000
# 吉林省    长春市/九台市  51.333333   43.0  2.333333
# 四川省    成都市       2.827586    1.0  1.026525
# 天津市    天津市       9.840580    2.0  1.246377
# 宁夏     银川市      22.833333   14.5  1.111111
# 安徽省    合肥市      13.000000    1.5  1.000000
# 山东省    济南市      19.634486   13.0  1.322934
# 山西省    太原市      20.416667   21.0  1.291667
# 广东省    广州市       5.959953    2.0  1.043286
# 广西     南宁市       1.529412    1.0  1.000000
# 江苏省    南京市      13.974194    3.0  1.235125
# 江西省    南昌市      15.548611    2.0  1.361111
# 河北省    石家庄市      2.883610    2.0  1.024941
# 河南省    郑州市       9.166867    2.0  1.092437
# 湖南省    长沙市      33.250000   30.0  1.625000
# 福建省    福州市       6.076495    1.0  1.059805
# 辽宁省    沈阳市      22.824121   19.0  1.241206
# 重庆市    重庆市       6.730897    2.0  1.058693
# ...
